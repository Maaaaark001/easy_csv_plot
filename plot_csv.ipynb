# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取CSV文件
data = pd.read_csv('RigolDS3.csv',skiprows=1)  # 替换为你的文件名

# 绘制所有列的图表
for column in data.columns:
    plt.plot(data[column], label=column)

plt.show()
